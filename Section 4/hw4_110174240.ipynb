# %% [markdown]
# # Homework no: 4
# ### Name : ANGGARA PUTRA PRATAMA - 1101174240
#
# github.com/anggaraputrapratama

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl

# %%
data = pd.read_csv ('Dengue_Daily_EN.csv', sep=',')
age = data.loc[:, 'Age_Group'].value_counts().head(10)
mpl.barh(age.keys(), age, color=['blue', 'green', 'red', 'purple', 'brown', 'pink', 'black', 'orange', 'grey', 'coral'])
# Out:
# <BarContainer object of 10 artists>

# %%
county = data.loc[:, 'County_living'].value_counts().head(10)
mpl.barh(county.keys(), age, color=['blue', 'green', 'red', 'purple', 'brown', 'pink', 'black', 'orange', 'grey', 'coral'])
# Out:
# <BarContainer object of 10 artists>

# %%
data['month'] = pd.DatetimeIndex(df['Date_Onset']).month
data['month'] = data.month.map("{:02}".format)

month = data['month'].value_counts().head(10)
month.plot(kind='barh', color=['blue', 'green', 'red', 'purple', 'brown', 'pink', 'black', 'orange', 'grey', 'coral'])
mpl.show()
